# %% [markdown]
# <a href="https://colab.research.google.com/github/jleacock2020/CourseraDataAnalystWork/blob/main/Tuples%2C%20Dictionaries%2C%20Lists%2C%20and%20Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tuples**
#
# In Python, list and tuple are a class of data structures that can store one or more objects or values. A list is used to store multiple items in one variable and can be created using square brackets. Similarly, tuples also can store multiple items in a single variable and can be declared using parentheses.

# %%
T=(23,45,67,89,67)  #immutable
print(T[4])
# Out:
# 67

# %%
T[2]=100
print(T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-4d2142a7eed2> in <cell line: 1>()
# ----> 1 T[2]=100
#       2 print(T)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ![python-list-tuple-set-array-dict-1.png](data:image/png;base64,...)

# %%
T=(2,3,4,5,6,9)

print(T[1:5])
# Out:
# (3, 4, 5, 6)

# %%
for x in T:
  if x==15:
    print("Found it")

# %% [markdown]
# **DICITIONARY :**
#
# Key:Value pair

# %%
D={'Geetu':98, 'Bunny':98, 'Joy':95,"Ronny":97}
print(D['Ronny'])
# Out:
# 97

# %%
D2={1:100,2:99,3:76,4:89,5:67}
print(D2.values())
# Out:
# dict_values([100, 99, 76, 89, 67])

# %%
D={10:100,2:97,3:56,4:78}
print(D[10])
# Out:
# 100

# %%
D={'Geetu':"White","Jasmine":"Pink","Guransh":"Red","Ronny":"Blue"}

D['Geetu']='White'

print(D)
# Out:
# {'Geetu': 'White', 'Jasmine': 'Pink', 'Guransh': 'Red', 'Ronny': 'Blue'}

# %%
print(D.items())
print(D)
# Out:
# dict_items([('Geetu', 'White'), ('Jasmine', 'Pink'), ('Guransh', 'Red'), ('Ronny', 'Blue')])
# {'Geetu': 'White', 'Jasmine': 'Pink', 'Guransh': 'Red', 'Ronny': 'Blue'}

# %%
#Update the existing value
D['Ronny']='Green'
print(D)
# Out:
# {'Geetu': 'Pink', 'Jasmine': 'Pink', 'Guransh': 'Red', 'Ronny': 'Green', 'Aarav': 'Green'}

# %%
#Delete an element
D.pop('Geetu')
print(D)
# Out:
# {'Jasmine': 'Pink', 'Guransh': 'Red', 'Ronny': 'Blue'}

# %%
#Delete item from the last one
D.popitem()
print(D)
# Out:
# {'Jasmine': 'Pink'}

# %%
#DYNAMIC DICITIONARY

Subj={}
ch='y'
while ch.lower()=='y':
   name=input("Enter your name:")
   s=input("Enter your fav subject:")
   Subj[name]=s
   ch=input("Continue?(y/n):")

print(Subj)
# Out:
# Enter your name:Geetu
# Enter your fav subject:Computer
# Continue?(y/n):y
# Enter your name:Jasmine
# Enter your fav subject:Math
# Continue?(y/n):y
# Enter your name:Ronny
# Enter your fav subject:English
# Continue?(y/n):n
# {'Geetu': 'Computer', 'Jasmine': 'Math', 'Ronny': 'English'}

# %% [markdown]
# **SETS**
#
# Sets are unordered collections of unique objects enclosed by curly braces{} — not to be confused with dictionaries which are also enclosed with curly braces.
#
# Unique means that a set cannot store duplicate values and are therefore very handy for removing duplicates from lists. You can store any python objects in a set. A set is created using Set={values}. You can convert a list into a set using Set(list).
#
# Sets have their own unique operations for merging two sets. These are union() function or | operator, intersection() function or & operator, and the difference() function or — operator

# %%
S={23,34,45,45,67,88}
print(S)
# Out:
# {34, 67, 23, 88, 45}

# %%
L=[23,23,45,67,78]
newlist=set(L)  #converted it into set
listn=list(newlist) #set to List datastructure
print(listn)
# Out:
# [67, 45, 78, 23]

# %%
# create a set of integer type
student_id = {112, 114, 116, 118, 115}
print('Student ID:', student_id)

# create a set of string type
vowel_letters = {'a', 'e', 'i', 'o', 'u'}
print('Vowel Letters:', vowel_letters)

# create a set of mixed data types
mixed_set = {'Hello', 101, -2, 'Bye'}
print('Set of mixed data types:', mixed_set)
# Out:
# Student ID: {112, 114, 115, 116, 118}
# Vowel Letters: {'a', 'u', 'o', 'e', 'i'}
# Set of mixed data types: {'Hello', 101, -2, 'Bye'}

# %%
# create an empty set
empty_set = set()

# create an empty dictionary
empty_dictionary = { }

# check data type of empty_set
print('Data type of empty_set:', type(empty_set))

# check data type of dictionary_set
print('Data type of empty_dictionary', type(empty_dictionary))
# Out:
# Data type of empty_set: <class 'set'>
# Data type of empty_dictionary <class 'dict'>

# %%
# Let's see what will happen if we try to include duplicate items in a set.

numbers = {2, 4, 6, 6, 2, 8}
print(numbers)
# Out:
# {8, 2, 4, 6}

# %%
numbers = {21, 34, 54, 12}

print('Initial Set:',numbers)

# using add() method
numbers.add(32)

print('Updated Set:', numbers)
# Out:
# Initial Set: {34, 12, 21, 54}
# Updated Set: {32, 34, 12, 21, 54}

# %%
companies = {'Lacoste', 'Ralph Lauren'}
tech_companies = ['apple', 'google', 'apple']

companies.update(tech_companies)

print(companies)

# Output: {'google', 'apple', 'Lacoste', 'Ralph Lauren'}

# %%
languages = {'Swift', 'Java', 'Python'}

print('Initial Set:',languages)

# remove 'Java' from a set
removedValue = languages.discard('Java')

print('Set after remove():', languages)

# %% [markdown]
# **Python Set Operations**
# Python Set provides different built-in methods to perform mathematical set operations like union, intersection, subtraction, and symmetric difference.
#
# **Union of Two Sets**
#
#
# The union of two sets A and B include all the elements of set A and B.

# %%
# first set
A = {1, 3, 5}

# second set
B = {0, 2, 4}

# perform union operation using |
print('Union using |:', A | B)

# perform union operation using union()
print('Union using union():', A.union(B))
# Out:
# Union using |: {0, 1, 2, 3, 4, 5}
# Union using union(): {0, 1, 2, 3, 4, 5}

# %% [markdown]
# **Set Intersection**
#
# The intersection of two sets A and B include the common elements between set A and B.

# %%
# first set
A = {1, 3, 5}

# second set
B = {1, 2, 3}

# perform intersection operation using &
print('Intersection using &:', A & B)

# perform intersection operation using intersection()
print('Intersection using intersection():', A.intersection(B))
# Out:
# Intersection using &: {1, 3}
# Intersection using intersection(): {1, 3}

# %% [markdown]
# **Difference between Two Sets**
#
#
# The difference between two sets A and B include elements of set A that are not present on set B.

# %%
# first set
A = {2, 3, 5}

# second set
B = {1, 2, 6}

# perform difference operation using &
print('Difference using &:', A - B)

# perform difference operation using difference()
print('Difference using difference():', A.difference(B))
# perform difference operation using difference()
print('Difference using difference():', B.difference(A))
# Out:
# Difference using &: {3, 5}
# Difference using difference(): {3, 5}
# Difference using difference(): {1, 6}

# %% [markdown]
# **The symmetric difference** between two sets A and B includes all elements of A and B without the common elements.
#
# ![python-symmetric-difference.png](data:image/png;base64,...)

# %%
# first set
A = {2, 3, 5}

# second set
B = {1, 2, 6}

# perform difference operation using &
print('using ^:', A ^ B)

# using symmetric_difference()
print('using symmetric_difference():', A.symmetric_difference(B))
# Out:
# using ^: {1, 3, 5, 6}
# using symmetric_difference(): {1, 3, 5, 6}

# %% [markdown]
# ![python-list-tuple-set-array-dict-2.png](data:image/png;base64,...)
