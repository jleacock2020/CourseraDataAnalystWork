# %% [markdown]
# <a href="https://colab.research.google.com/github/jleacock2020/CourseraDataAnalystWork/blob/main/FileHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reading Text Files**
#
# One way to read or write a file in Python is to use the built-in open function. The open function provides a File object that contains the methods and attributes you need in order to read, save, and manipulate the file. In this notebook, we will only cover .txt files. The first parameter you need is the file path and the file name. An example is shown as follow:

# %% [markdown]
# ![ReadOpen.png](data:image/png;base64,...)

# %% [markdown]
# The mode argument is optional and the default value is r.
#
#
# "r"	- Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a"	- Append - Opens a file for appending, creates the file if it does not exist
#
# "w"	- Write - Opens a file for writing, creates the file if it does not exist
#
# "x"	- Create - Creates the specified file, returns an error if the file exists
#
# In addition you can specify if the file should be handled as binary or text mode
#
# "t"	- Text - Default value. Text mode
#
# "b"	- Binary - Binary mode (e.g. images)

# %% [markdown]
# **OPEN ()**

# %%
file1 = open("Example1.txt", "r")

print(file1.name)
print(file1.mode)
# Out:
# Example1.txt
# r

# %% [markdown]
# **READ()**

# %%
#We can read the file and assign it to a variable :
data=file1.read()
print(data)
#print(type(data))

# %% [markdown]
# **READ(NUM)**

# %%
f = open("Example1.txt", "r")
print(f.read(10))
# Out:
# Hello!
# How

# %% [markdown]
# **READLINE()**

# %%
#Let's use readline()
data2=file1.readline()
print(data2)

# When a file is opened, an input marker is positioned at the beginning of the file
# • The readline() method reads the text, starting at the current position and continuing until the end of the line is encountered
# • The input marker is then moved to the next line

# %% [markdown]
# **READLINES**

# %%
f = open("Example1.txt", "r")
print(f.readlines())
# Out:
# ['Hello!\n', 'How are you doing?\n', 'I am doing Well. Thank you For asking.\n', 'See you again!\n']

# %% [markdown]
# **Loop through the file line by line:**

# %%
f = open("Example1.txt", "r")
count=0
for x in f:
  count=count+1
  print(count,x)

print(count)
# Out:
# 1 Hello!
#
# 2 How are you doing?
#
# 3 I am doing Well. Thank you For asking.
#
# 4 See you again!
#
# 4

# %% [markdown]
# **CLOSE()**

# %%
#We must close the file
file1.close()

# %% [markdown]
# **SEEK() AND TELL()**

# %%
# Again set the pointer to the beginning
file1.seek(10,0)
data2=file1.read()
print(data2)
print(file1.tell())

# offset - This is the position of the read/write pointer within the file.

# whence- This is optional and defaults to 0 which means absolute file positioning,
# other values are 1 which means seek relative to the current position and 2 means seek relative to the file's end.
# Out:
# w are you doing?
# I am doing Well. Thank you For asking.
# See you again!
#
# 84

# %%
# The tell() method tells you the current position within the file;
# in other words, the next read or write will occur at that many bytes from the beginning of the file.

# The seek(offset[, from]) method changes the current file position. The offset argument indicates the number of bytes to be moved.
# The from argument specifies the reference position from where the bytes are to be moved.

# If from is set to 0, it means use the beginning of the file as the reference position and 1 means use the current position
# as the reference position and if it is set to 2 then the end of the file would be taken as the reference position.

# %% [markdown]
# ![files.png](data:image/png;base64,...)

# %%
#converting input
infile = open("Example1.txt", "r")
count=0
for line in infile:
    count=count+1
    print(count, line)
    if count==5 or count==6 or count==7:
      d=int(line)
      print(type(d))

# %% [markdown]
# **WRITING TO A FILE**
#
# - Create - will create a file, returns an error if the file exist
#
# - Append - will create a file if the specified file does not exist
#
# - Write - will create a file if the specified file does not exist
#
#
# **WRITE()**

# %%
#Writing to a file
file2=open("Example1.txt","w")
strdata="Hello!\nHow are you doing?\nI am doing Well.!\n Bye bye-87845857"

file2.write(strdata)
file2.close()

# %%
file3=open("Example1.txt","r")
data=file3.read()
print(data)
# Out:
# Hello!
# How are you doing?
# I am doing Well.!
#  Bye bye-87845857
#  Geetu Geetu!

# %% [markdown]
# **APPEND TO A FILE**

# %%
#Append
#Writing to a file
file2=open("Example1.txt","a")
strdata="\n Geetu Geetu!"
file2.write(strdata)
file2.close()

# %% [markdown]
# **OPEN A NEW FILE THAT DOES NOT ALREADY EXIST**

# %%
#open a new file f it doesnt already exist

file2=open("Example3.txt","x")
strdata="Geetu Geetu!"
file2.write(strdata)
file2.close()

# %%
file3=open("Example3.txt","r")
data=file3.read()
print(data)
# Out:
# Geetu Geetu!

# %% [markdown]
# **WITH**
#
# **The with statement automatically closes the file after you’ve completed writing it.**
# The with statement is a replacement for commonly used try/finally error-handling statements. A common example of using the with statement is opening a file. To open and write to a file in Python, you can use the with statement as follows:

# %%
with open("Example1.txt", "w") as file4 :
# Write output to outfile

# This with statement opens the file with the given name, sets outfile to
# the file object, and closes the file object when the end of the
# statement has been reached or an exception is raised

# %% [markdown]
# **USE OF STRING FUNCTIONS WHILE READING FILES**

# %% [markdown]
# There are times when you want to read input by:
#
# • Each line
#
# • Each word
#
# • A single character
#
# • Python can treat an input file as though it were a container of strings
# in which each line comprises an individual string
# • You can then use string methods to process the text the way you want
# • Two useful methods for text processing which are commonly used are
# **split() and strip()**

# %% [markdown]
# ![strip.png](data:image/png;base64,...)

# %%
# To remove the newline character, apply the rstrip() method to the string:
line = data.strip()
print(line)
# Out:
# Geetu Geetu!

# %%
# Sometimes you may need to read the individual words from a text file
# • For example, suppose our input file contains two lines of text
# Mary had a little lamb,
# whose fleece was white as snow

line = line.strip("!")
wordlist = line.split()
print(wordlist)
print(len(wordlist))

# The split method splits the string at each blank space
# Out:
# ['Geetu', 'Geetu']
# 2

# %%
with open("Example1.txt") as data:
    for line in data:
        line = line.strip(".!?")
        line = line.split()
        print(line)
# Out:
# ['Hello!']
# ['How', 'are', 'you', 'doing?']
# ['I', 'am', 'doing', 'Well.!']
# ['Bye', 'bye-87845857']
# ['Geetu', 'Geetu']

# %%
# • How to remove comma from the last word “lamb,”
word = word.rstrip(".,?!")

# %% [markdown]
# ![strip.png](data:image/png;base64,...)

# %%
#Q3 Write a Python program to read last n lines of mytxt file
#[Hint: write a function]
def read_last_n_lines(n):
    with open("Example1.txt") as myfile:
        lines = myfile.readlines()
        last_lines =lines[-n:]
        listToStr = '\n'.join(map(str,last_lines))
        return listToStr

lines=int(input("How many do you wish to read?"))
print(read_last_n_lines(lines))
# Out:
# How many do you wish to read?2
#  Bye bye-87845857
#
#  Geetu Geetu!

# %%
#Q4 count the number of lines in mytxt file
count=0
with open("Example1.txt") as myfile:
    for i in myfile:
      count=count+1
print("Number of lines:",count)
# Out:
# Number of lines: 4

# %%
# Q8 Write a python program to find the longest word in mytxt file
def LongestWord(file):
    with open(file) as files:
        words = files.read().split()
    max_len = len(max(words, key=len))
    return[word for word in words if len(word)==max_len]
LongestWord("mytxt.txt")

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)
